# %%
#Lambda

def add(x, y):
    return x - y

addit = lambda x, y : x - y

print(add(4,2))

print(addit(4,2))

#map(), filter(), and sorted()
# Out:
# 2
# 2

# %% [markdown]
# Bonfire >>> 30% to step 160 for 24th | 45 to 59 | Lab 4 and Workshop 6

# %%
#list comprehension
even_numbers = [num for num in range(21) if num % 2 == 0]
print(even_numbers)
